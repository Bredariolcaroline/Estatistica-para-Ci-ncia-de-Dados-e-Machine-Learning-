# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:/users/carol/downloads/house_prices.csv')

# %%
df.drop(labels = ['id','date', 'sqft_living15', 'sqft_lot15'], axis = 1, inplace=True)
df
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      221900.0         3       1.00         1180      5650     1.0
# 1      538000.0         3       2.25         2570      7242     2.0
# 2      180000.0         2       1.00          770     10000     1.0
# 3      604000.0         4       3.00         1960      5000     1.0
# 4      510000.0         3       2.00         1680      8080     1.0
# ...         ...       ...        ...          ...       ...     ...
# 21608  360000.0         3       2.50         1530      1131     3.0
# 21609  400000.0         4       2.50         2310      5813     2.0
# 21610  402101.0         2       0.75         1020      1350     2.0
# 21611  400000.0         3       2.50         1600      2388     2.0
# 21612  325000.0         2       0.75         1020      1076     2.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0               0     0          3      7        1180              0
# ...

# %%
df.corr()
# Out:
#                   price  bedrooms  bathrooms  sqft_living  sqft_lot    floors  \
# price          1.000000  0.308350   0.525138     0.702035  0.089661  0.256794
# bedrooms       0.308350  1.000000   0.515884     0.576671  0.031703  0.175429
# bathrooms      0.525138  0.515884   1.000000     0.754665  0.087740  0.500653
# sqft_living    0.702035  0.576671   0.754665     1.000000  0.172826  0.353949
# sqft_lot       0.089661  0.031703   0.087740     0.172826  1.000000 -0.005201
# floors         0.256794  0.175429   0.500653     0.353949 -0.005201  1.000000
# waterfront     0.266369 -0.006582   0.063744     0.103818  0.021604  0.023698
# view           0.397293  0.079532   0.187737     0.284611  0.074710  0.029444
# condition      0.036362  0.028472  -0.124982    -0.058753 -0.008958 -0.263768
# grade          0.667434  0.356967   0.664983     0.762704  0.113621  0.458183
# sqft_above     0.605567  0.477600   0.685342     0.876597  0.183512  0.523885
# ...

# %%
import seaborn as sns

# %%
sns.scatterplot(df['sqft_living'], df['price']);
# Out:
# C:\Users\carol\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.scatterplot(df['long'], df['price']);
# Out:
# C:\Users\carol\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.heatmap(df.corr());

# %%
import matplotlib.pyplot as plt
fig,ax = plt.subplots(figsize=(15,15))
ax = sns.heatmap(df.corr(),annot=True)

# %%
sns.scatterplot(df['grade'], df['price']);
# Out:
# C:\Users\carol\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# !pip install yellowbrick --upgrade
# Out:
# ...
#      -------------------------------------- 282.6/282.6 kB 1.3 MB/s eta 0:00:00
# ...
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\carol\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\carol\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\carol\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\carol\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\carol\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\carol\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\carol\anaconda3\lib\site-packages)

# %%
from yellowbrick.target import FeatureCorrelation

# %%
df.columns[1:]
# Out:
# Index(['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long'],
#       dtype='object')

# %%
grafico = FeatureCorrelation(labels= df.columns[1:])
grafico.fit(df.iloc[:,1:16].values,df.iloc[:,0].values)
grafico.show();
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3976\1124538235.py in <module>
#       1 grafico = FeatureCorrelation(labels= df.columns[1:])
# ----> 2 grafico.fit(df.iloc[:,1:16].values,df.iloc[:,0].values)
#       3 grafico.show();
#
# ~\anaconda3\lib\site-packages\yellowbrick\target\feature_correlation.py in fit(self, X, y, **kwargs)
#     190             self.features_ = self.features_[sort_idx]
#     191
# --> 192         self.draw()
#     193         return self
#     194
#
# ~\anaconda3\lib\site-packages\yellowbrick\target\feature_correlation.py in draw(self)
#     203         # Set the labels for the bars
#     204         self.ax.set_yticks(pos)
# --> 205         self.ax.set_yticklabels(self.features_)
#     206
#     207         return self.ax
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in wrapper(self, *args, **kwargs)
# ...
